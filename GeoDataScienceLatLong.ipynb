# %%
# @hidden_cell
# The project token is an authorization token that is used to access project resources like data sources, connections, and used by platform APIs.
from project_lib import Project
project = Project(project_id='bcdfc3fb-8b77-4f7e-a4a0-999840f93be5', project_access_token='p-d24fb1b3677f7be276253b9b77aa1cebf219a7ac')
pc = project.project_context

# %%
! pip install opencage

# %%
from opencage.geocoder import OpenCageGeocode
from pprint import pprint

# %%
key = 'd493e62ce8d246499b1284168e580ba8'
geocoder = OpenCageGeocode(key)

# %%
import types
import pandas as pd
from botocore.client import Config
import ibm_boto3

def __iter__(self): return 0

# @hidden_cell
# The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
# You might want to remove those credentials before you share the notebook.
client_13c5f23e088e4651bc569838bd3166ec = ibm_boto3.client(service_name='s3',
    ibm_api_key_id='D7dgshw8K8_2UknjqSOB6TgmmOod-IMOmOWKQrUmQ5J2',
    ibm_auth_endpoint="https://iam.ng.bluemix.net/oidc/token",
    config=Config(signature_version='oauth'),
    endpoint_url='https://s3-api.us-geo.objectstorage.service.networklayer.com')

body = client_13c5f23e088e4651bc569838bd3166ec.get_object(Bucket='datascience320finalproject-donotdelete-pr-oghkbzvbwhznzj',Key='Ready_ComputerMath.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

df1 = pd.read_csv(body)
df1.head()
# Out:
#                            City     State  \
# 0                     Anchorage   Alaska
# 1                     Fairbanks   Alaska
# 2  Anniston-Oxford-Jacksonville  Alabama
# 3                Auburn-Opelika  Alabama
# 4             Birmingham-Hoover  Alabama
#
#                                    title  a_mean
# 0  Computer and Mathematical Occupations   40.13
# 1  Computer and Mathematical Occupations   36.80
# 2  Computer and Mathematical Occupations   29.98
# 3  Computer and Mathematical Occupations   34.29
# 4  Computer and Mathematical Occupations   38.58

# %%
list_lat = []   # create empty lists

list_long = []


	
for index, row in df1.iterrows(): # iterate over rows in dataframe



    City = row['City']
    State = row['State']       
    query = str(City)+','+str(State)

    results = geocoder.geocode(query)   
    lat = results[0]['geometry']['lat']
    long = results[0]['geometry']['lng']

    list_lat.append(lat)
    list_long.append(long)

	
# create new columns from lists

# %%
df1['lat'] = list_lat   

df1['lon'] = list_long

# %%
df1
# Out:
#                                      City           State  \
# 0                               Anchorage         Alaska
# 1                               Fairbanks         Alaska
# 2            Anniston-Oxford-Jacksonville        Alabama
# 3                          Auburn-Opelika        Alabama
# 4                       Birmingham-Hoover        Alabama
# 5                   Daphne-Fairhope-Foley        Alabama
# 6                                 Decatur        Alabama
# 7                                  Dothan        Alabama
# 8                  Florence-Muscle Shoals        Alabama
# 9                                 Gadsden        Alabama
# 10                             Huntsville        Alabama
# 11                                 Mobile        Alabama
# 12                             Montgomery        Alabama
# 13                             Tuscaloosa        Alabama
# 14         Fayetteville-Springdale-Rogers       Arkansas
# ...

# %%
df_ComputerMathPayRange = df1[['a_mean','lat','lon']]
df_ComputerMathPayRange
# Out:
#      a_mean        lat         lon
# 0     40.13  61.216313 -149.894852
# 1     36.80  64.837845 -147.716675
# 2     29.98  33.752933  -85.784955
# 3     34.29  32.611121  -85.437537
# 4     38.58  33.370890  -86.814073
# 5     33.25  30.406590  -87.683600
# 6     32.32  34.618810  -87.051507
# 7     33.13  31.223743  -85.393391
# 8     27.36  34.757526  -87.655901
# 9     32.79  34.010929  -85.998960
# 10    46.80  34.729847  -86.585901
# 11    36.32  30.694357  -88.043054
# 12    38.70  32.366966  -86.300648
# 13    32.01  33.209561  -87.567526
# 14    34.96  36.042826  -94.233876
# 15    31.59  35.387222  -94.424898
# 16    27.88  34.503839  -93.055244
# 17    24.96  35.842865  -90.703452
# 18    33.55  34.708985  -92.235641
# 19    28.85  34.215706  -92.014040
# 20    34.31  35.198752 -111.651823
# 21    29.36  34.509740 -114.347971
# 22    40.32  33.509210 -111.899030
# 23    32.70  34.539996 -112.468762
# 24    42.24  31.557415 -110.285414
# 25    39.41  32.222876 -110.974848
# ...

# %%
df_ComputerMathPayRange.describe()
# Out:
#            a_mean         lat         lon
# count  378.000000  378.000000  378.000000
# mean    36.015952   38.070035  -92.285095
# std      5.276249    5.479741   16.113244
# min     21.370000   20.242320 -168.021815
# 25%     32.442500   34.239465  -98.285447
# 50%     34.910000   38.961911  -87.561687
# 75%     39.165000   41.878200  -81.073985
# max     61.080000   64.837845  -68.777814

# %%
# create empty lists

list_PayRange1 = []


	
for index, row in df_ComputerMathPayRange.iterrows(): # iterate over rows in dataframe



    query = row['a_mean']
    if query <= 33:
        level = 'low Pay'
    elif query <= 40:
        level = 'Medium Pay'
    elif query > 40:
        level = 'High Pay'
    list_PayRange1.append(level)
	
# create new columns from lists

# %%
df_ComputerMathPayRange['PayRange'] =list_PayRange1
# Out:
# /opt/conda/envs/Python36/lib/python3.6/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
df_ComputerMathPayRange
# Out:
#      a_mean        lat         lon    PayRange
# 0     40.13  61.216313 -149.894852    High Pay
# 1     36.80  64.837845 -147.716675  Medium Pay
# 2     29.98  33.752933  -85.784955     low Pay
# 3     34.29  32.611121  -85.437537  Medium Pay
# 4     38.58  33.370890  -86.814073  Medium Pay
# 5     33.25  30.406590  -87.683600  Medium Pay
# 6     32.32  34.618810  -87.051507     low Pay
# 7     33.13  31.223743  -85.393391  Medium Pay
# 8     27.36  34.757526  -87.655901     low Pay
# 9     32.79  34.010929  -85.998960     low Pay
# 10    46.80  34.729847  -86.585901    High Pay
# 11    36.32  30.694357  -88.043054  Medium Pay
# 12    38.70  32.366966  -86.300648  Medium Pay
# 13    32.01  33.209561  -87.567526     low Pay
# 14    34.96  36.042826  -94.233876  Medium Pay
# 15    31.59  35.387222  -94.424898     low Pay
# 16    27.88  34.503839  -93.055244     low Pay
# 17    24.96  35.842865  -90.703452     low Pay
# 18    33.55  34.708985  -92.235641  Medium Pay
# ...

# %%
project.save_data(data=df_ComputerMathPayRange.to_csv(index=False),file_name='MapComputerMath.csv',overwrite=True)
# Out:
# {'file_name': 'MapComputerMath.csv',
#  'message': 'File saved to project storage.',
#  'bucket_name': 'datascience320finalproject-donotdelete-pr-oghkbzvbwhznzj',
#  'asset_id': '1f151ea9-327c-463d-90d4-03b6d31f67d1'}
