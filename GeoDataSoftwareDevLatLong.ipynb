# %%
# @hidden_cell
# The project token is an authorization token that is used to access project resources like data sources, connections, and used by platform APIs.
from project_lib import Project
project = Project(project_id='bcdfc3fb-8b77-4f7e-a4a0-999840f93be5', project_access_token='p-d24fb1b3677f7be276253b9b77aa1cebf219a7ac')
pc = project.project_context

# %%
! pip install opencage

# %%
from opencage.geocoder import OpenCageGeocode
from pprint import pprint

# %%
key = 'd493e62ce8d246499b1284168e580ba8'
geocoder = OpenCageGeocode(key)

# %%
import types
import pandas as pd
from botocore.client import Config
import ibm_boto3

def __iter__(self): return 0

# @hidden_cell
# The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
# You might want to remove those credentials before you share the notebook.
client_13c5f23e088e4651bc569838bd3166ec = ibm_boto3.client(service_name='s3',
    ibm_api_key_id='D7dgshw8K8_2UknjqSOB6TgmmOod-IMOmOWKQrUmQ5J2',
    ibm_auth_endpoint="https://iam.ng.bluemix.net/oidc/token",
    config=Config(signature_version='oauth'),
    endpoint_url='https://s3-api.us-geo.objectstorage.service.networklayer.com')

body = client_13c5f23e088e4651bc569838bd3166ec.get_object(Bucket='datascience320finalproject-donotdelete-pr-oghkbzvbwhznzj',Key='Ready_Soft_Dev.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

df1 = pd.read_csv(body)
df1.head()
# Out:
#                 City     State                              title  a_mean
# 0          Anchorage   Alaska   Software Developers, Applications   52.53
# 1     Auburn-Opelika  Alabama   Software Developers, Applications   39.80
# 2  Birmingham-Hoover  Alabama   Software Developers, Applications   41.90
# 3            Decatur  Alabama   Software Developers, Applications   41.43
# 4         Huntsville  Alabama   Software Developers, Applications   50.09

# %%
list_lat = []   # create empty lists

list_long = []


	
for index, row in df1.iterrows(): # iterate over rows in dataframe



    City = row['City']
    State = row['State']       
    query = str(City)+','+str(State)

    results = geocoder.geocode(query)   
    lat = results[0]['geometry']['lat']
    long = results[0]['geometry']['lng']

    list_lat.append(lat)
    list_long.append(long)

	
# create new columns from lists

# %%
df1['lat'] = list_lat   

df1['lon'] = list_long

# %%
df1
# Out:
#                                      City           State  \
# 0                               Anchorage         Alaska
# 1                          Auburn-Opelika        Alabama
# 2                       Birmingham-Hoover        Alabama
# 3                                 Decatur        Alabama
# 4                              Huntsville        Alabama
# 5                                  Mobile        Alabama
# 6                              Montgomery        Alabama
# 7          Fayetteville-Springdale-Rogers       Arkansas
# 8                              Fort Smith       Arkansas
# 9                               Jonesboro       Arkansas
# 10   Little Rock-North Little Rock-Conway       Arkansas
# 11                              Flagstaff        Arizona
# 12               Lake Havasu City-Kingman        Arizona
# 13                Phoenix-Mesa-Scottsdale        Arizona
# 14                   Sierra Vista-Douglas        Arizona
# ...

# %%
df_SoftPayRange = df1[['a_mean','lat','lon']]
df_SoftPayRange.head()
# Out:
#    a_mean        lat         lon
# 0   52.53  61.216313 -149.894852
# 1   39.80  32.611121  -85.437537
# 2   41.90  33.370890  -86.814073
# 3   41.43  34.618810  -87.051507
# 4   50.09  34.729847  -86.585901

# %%
df_SoftPayRange.describe()
# Out:
#            a_mean         lat         lon
# count  305.000000  305.000000  305.000000
# mean    43.780164   38.252712  -92.231631
# std      6.272165    5.366453   16.197469
# min     21.810000   20.242320 -168.021815
# 25%     39.410000   34.729847  -98.125735
# 50%     43.290000   39.158168  -87.714530
# 75%     48.030000   42.037250  -80.624079
# max     69.250000   61.216313  -68.777814

# %%
# create empty lists

list_PayRange = []


	
for index, row in df_SoftPayRange.iterrows(): # iterate over rows in dataframe



    query = row['a_mean']
    if query <= 40:
        level = 'low Pay'
    elif query <= 50:
        level = 'Medium Pay'
    elif query > 50:
        level = 'High Pay'
    list_PayRange.append(level)
	
# create new columns from lists

# %%
df_SoftPayRange['PayRange'] =list_PayRange
# Out:
# /opt/conda/envs/Python36/lib/python3.6/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
df_SoftPayRange
# Out:
#      a_mean        lat         lon    PayRange
# 0     52.53  61.216313 -149.894852    High Pay
# 1     39.80  32.611121  -85.437537     low Pay
# 2     41.90  33.370890  -86.814073  Medium Pay
# 3     41.43  34.618810  -87.051507  Medium Pay
# 4     50.09  34.729847  -86.585901    High Pay
# 5     43.37  30.694357  -88.043054  Medium Pay
# 6     43.29  32.366966  -86.300648  Medium Pay
# 7     43.51  36.042826  -94.233876  Medium Pay
# 8     40.17  35.387222  -94.424898  Medium Pay
# 9     30.84  35.842865  -90.703452     low Pay
# 10    40.95  34.708985  -92.235641  Medium Pay
# 11    42.63  35.198752 -111.651823  Medium Pay
# 12    39.38  34.509740 -114.347971     low Pay
# 13    48.03  33.509210 -111.899030  Medium Pay
# 14    45.21  31.557415 -110.285414  Medium Pay
# 15    40.87  32.222876 -110.974848  Medium Pay
# 16    54.42  35.373871 -119.019464    High Pay
# 17    52.31  39.728494 -121.837478    High Pay
# 18    52.15  36.739442 -119.784831    High Pay
# ...

# %%
project.save_data(data=df_SoftPayRange.to_csv(index=False),file_name='SoftAppDevPayRange.csv',overwrite=True)
# Out:
# {'file_name': 'SoftAppDevPayRange.csv',
#  'message': 'File saved to project storage.',
#  'bucket_name': 'datascience320finalproject-donotdelete-pr-oghkbzvbwhznzj',
#  'asset_id': '995e79af-77c9-40ff-899e-e94e0557fafd'}
